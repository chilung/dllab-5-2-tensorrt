# %%
### IMPORTANT!!!
# Due to some environment bug. tensorrt cannot be found while python is launched in Chilung/tensorrt working directory.
# %matplotlib inline

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# %%
from __future__ import print_function, division

import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
print(torch.__version__)
# Out:
# 1.0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib.animation as animation
import matplotlib.patches as mpatches

from torch.autograd import Variable
import torch
import math

import os
import sys
import re
from collections import OrderedDict

def test_result(fname):

    dictionary_acc = OrderedDict()
    dictionary_time = OrderedDict()
    
    with open(fname) as fp:  
        for cnt, line in enumerate(fp):
            print("Line {}: {}".format(cnt, line))
            # batch size: 2
            pattern = re.compile(r"batch size: (\d+)")
            match = pattern.match(line)
            if match:
                batch_size_str, = match.groups()
                print(batch_size_str)
                      
            # Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
            pattern = re.compile(r"Accuracy of the network on the (\d+) test images: (\d+.\d+)%, and loss is: (\d+.\d+)")
            match = pattern.match(line)
            if match:
                test_size_str, acc_str, loss_str = match.groups()
                print(test_size_str, acc_str, loss_str)

            # 76.6552894115448 seconds
            pattern = re.compile(r"(\d+.\d+) seconds")
            match = pattern.match(line)
            if match:
                time_str, = match.groups()
                print(time_str)
                print('batch: {:s}, acc: {:s}, time: {:s}'.
                      format(batch_size_str, acc_str, time_str))

                batch = int(math.log(int(batch_size_str), 2))
                acc = float("{:.2f}".format(float(acc_str)))
                time = float("{:.2f}".format(float(time_str)))
                
                dictionary_acc[batch] = acc
                dictionary_time[batch] = time
                    
    return dictionary_acc, dictionary_time

pytorch_gpu_acc, pytorch_gpu_time = test_result("pytorch-gpu-test-result.log")
rt_acc, rt_time = test_result("rt_batch_size.log")
# Out:
# Line 0: batch size: 2
#
# 2
# Line 1: test data set: test
#
# Line 2:
#
# Line 3: /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/ipykernel_launcher.py:43: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#
# Line 4:
#
# Line 5: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
#
# 3347 92.41 0.118
# Line 6: Accuracy of Bread : 88 %
#
# Line 7: Accuracy of DairyProduct : 81 %
#
# Line 8: Accuracy of Dessert : 97 %
#
# Line 9: Accuracy of   Egg : 88 %
#
# Line 10: Accuracy of Friedfood : 92 %
#
# Line 11: Accuracy of  Meat : 91 %
#
# Line 12: Accuracy of Noodles-Pasta : 92 %
#
# Line 13: Accuracy of  Rice : 98 %
#
# Line 14: Accuracy of Seafood : 98 %
#
# Line 15: Accuracy of  Soup : 91 %
#
# Line 16: Accuracy of Vegetable-Fruit : 97 %
#
# Line 17: 41.08022952079773 seconds
#
# 41.08022952079773
# batch: 2, acc: 92.41, time: 41.08022952079773
# Line 18: batch size: 4
#
# 4
# Line 19: test data set: test
#
# Line 20: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
#
# 3347 92.41 0.059
# Line 21: Accuracy of Bread : 88 %
#
# Line 22: Accuracy of DairyProduct : 81 %
#
# Line 23: Accuracy of Dessert : 97 %
#
# Line 24: Accuracy of   Egg : 88 %
#
# Line 25: Accuracy of Friedfood : 92 %
#
# Line 26: Accuracy of  Meat : 91 %
#
# Line 27: Accuracy of Noodles-Pasta : 92 %
#
# Line 28: Accuracy of  Rice : 98 %
#
# Line 29: Accuracy of Seafood : 98 %
#
# Line 30: Accuracy of  Soup : 91 %
#
# Line 31: Accuracy of Vegetable-Fruit : 97 %
#
# Line 32: 39.71622061729431 seconds
#
# 39.71622061729431
# batch: 4, acc: 92.41, time: 39.71622061729431
# Line 33: batch size: 8
#
# 8
# Line 34: test data set: test
#
# Line 35: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
#
# 3347 92.41 0.029
# Line 36: Accuracy of Bread : 88 %
#
# Line 37: Accuracy of DairyProduct : 81 %
#
# Line 38: Accuracy of Dessert : 97 %
#
# Line 39: Accuracy of   Egg : 88 %
#
# Line 40: Accuracy of Friedfood : 92 %
#
# Line 41: Accuracy of  Meat : 91 %
#
# Line 42: Accuracy of Noodles-Pasta : 92 %
#
# Line 43: Accuracy of  Rice : 98 %
#
# Line 44: Accuracy of Seafood : 98 %
#
# Line 45: Accuracy of  Soup : 91 %
#
# Line 46: Accuracy of Vegetable-Fruit : 97 %
#
# Line 47: 39.40698456764221 seconds
#
# 39.40698456764221
# batch: 8, acc: 92.41, time: 39.40698456764221
# Line 48: batch size: 16
#
# 16
# Line 49: test data set: test
#
# Line 50: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
#
# 3347 92.41 0.015
# Line 51: Accuracy of Bread : 88 %
#
# Line 52: Accuracy of DairyProduct : 81 %
#
# Line 53: Accuracy of Dessert : 97 %
#
# Line 54: Accuracy of   Egg : 88 %
#
# Line 55: Accuracy of Friedfood : 92 %
#
# Line 56: Accuracy of  Meat : 91 %
#
# Line 57: Accuracy of Noodles-Pasta : 92 %
#
# Line 58: Accuracy of  Rice : 98 %
#
# Line 59: Accuracy of Seafood : 98 %
#
# Line 60: Accuracy of  Soup : 91 %
#
# Line 61: Accuracy of Vegetable-Fruit : 97 %
#
# Line 62: 39.805410861968994 seconds
#
# 39.805410861968994
# batch: 16, acc: 92.41, time: 39.805410861968994
# Line 63: batch size: 32
#
# 32
# Line 64: test data set: test
#
# Line 65: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 66: Accuracy of Bread : 88 %
#
# Line 67: Accuracy of DairyProduct : 81 %
#
# Line 68: Accuracy of Dessert : 97 %
#
# Line 69: Accuracy of   Egg : 88 %
#
# Line 70: Accuracy of Friedfood : 92 %
#
# Line 71: Accuracy of  Meat : 91 %
#
# Line 72: Accuracy of Noodles-Pasta : 92 %
#
# Line 73: Accuracy of  Rice : 98 %
#
# Line 74: Accuracy of Seafood : 98 %
#
# Line 75: Accuracy of  Soup : 91 %
#
# Line 76: Accuracy of Vegetable-Fruit : 97 %
#
# Line 77: 38.876230001449585 seconds
#
# 38.876230001449585
# batch: 32, acc: 92.41, time: 38.876230001449585
# Line 78: batch size: 64
#
# 64
# Line 79: test data set: test
#
# Line 80: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
#
# 3347 92.41 0.004
# Line 81: Accuracy of Bread : 88 %
#
# Line 82: Accuracy of DairyProduct : 81 %
#
# Line 83: Accuracy of Dessert : 97 %
#
# Line 84: Accuracy of   Egg : 88 %
#
# Line 85: Accuracy of Friedfood : 92 %
#
# Line 86: Accuracy of  Meat : 91 %
#
# Line 87: Accuracy of Noodles-Pasta : 92 %
#
# Line 88: Accuracy of  Rice : 98 %
#
# Line 89: Accuracy of Seafood : 98 %
#
# Line 90: Accuracy of  Soup : 91 %
#
# Line 91: Accuracy of Vegetable-Fruit : 97 %
#
# Line 92: 39.156503200531006 seconds
#
# 39.156503200531006
# batch: 64, acc: 92.41, time: 39.156503200531006
# Line 93: batch size: 128
#
# 128
# Line 94: test data set: test
#
# Line 95: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
#
# 3347 92.41 0.002
# Line 96: Accuracy of Bread : 88 %
#
# Line 97: Accuracy of DairyProduct : 81 %
#
# Line 98: Accuracy of Dessert : 97 %
#
# Line 99: Accuracy of   Egg : 88 %
#
# Line 100: Accuracy of Friedfood : 92 %
#
# Line 101: Accuracy of  Meat : 91 %
#
# Line 102: Accuracy of Noodles-Pasta : 92 %
#
# Line 103: Accuracy of  Rice : 98 %
#
# Line 104: Accuracy of Seafood : 98 %
#
# Line 105: Accuracy of  Soup : 91 %
#
# Line 106: Accuracy of Vegetable-Fruit : 97 %
#
# Line 107: 39.112802267074585 seconds
#
# 39.112802267074585
# batch: 128, acc: 92.41, time: 39.112802267074585
# Line 108: batch size: 256
#
# 256
# Line 109: test data set: test
#
# Line 110: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
#
# 3347 92.41 0.001
# Line 111: Accuracy of Bread : 88 %
#
# Line 112: Accuracy of DairyProduct : 81 %
#
# Line 113: Accuracy of Dessert : 97 %
#
# Line 114: Accuracy of   Egg : 88 %
#
# Line 115: Accuracy of Friedfood : 92 %
#
# Line 116: Accuracy of  Meat : 91 %
#
# Line 117: Accuracy of Noodles-Pasta : 92 %
#
# Line 118: Accuracy of  Rice : 98 %
#
# Line 119: Accuracy of Seafood : 98 %
#
# Line 120: Accuracy of  Soup : 91 %
#
# Line 121: Accuracy of Vegetable-Fruit : 97 %
#
# Line 122: 39.5123827457428 seconds
#
# 39.5123827457428
# batch: 256, acc: 92.41, time: 39.5123827457428
# Line 123:
#
# Line 0: batch size: 2
#
# 2
# Line 1: test data set: test
#
# Line 2: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
#
# 3347 92.41 0.118
# Line 3: Accuracy of Bread : 88 %
#
# Line 4: Accuracy of DairyProduct : 81 %
#
# Line 5: Accuracy of Dessert : 97 %
#
# Line 6: Accuracy of   Egg : 88 %
#
# Line 7: Accuracy of Friedfood : 92 %
#
# Line 8: Accuracy of  Meat : 91 %
#
# Line 9: Accuracy of Noodles-Pasta : 92 %
#
# Line 10: Accuracy of  Rice : 98 %
#
# Line 11: Accuracy of Seafood : 98 %
#
# Line 12: Accuracy of  Soup : 91 %
#
# Line 13: Accuracy of Vegetable-Fruit : 97 %
#
# Line 14: 41.15637135505676 seconds
#
# 41.15637135505676
# batch: 2, acc: 92.41, time: 41.15637135505676
# Line 15: batch size: 4
#
# 4
# Line 16: test data set: test
#
# Line 17: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
#
# 3347 92.41 0.059
# Line 18: Accuracy of Bread : 88 %
#
# Line 19: Accuracy of DairyProduct : 81 %
#
# Line 20: Accuracy of Dessert : 97 %
#
# Line 21: Accuracy of   Egg : 88 %
#
# Line 22: Accuracy of Friedfood : 92 %
#
# Line 23: Accuracy of  Meat : 91 %
#
# Line 24: Accuracy of Noodles-Pasta : 92 %
#
# Line 25: Accuracy of  Rice : 98 %
#
# Line 26: Accuracy of Seafood : 98 %
#
# Line 27: Accuracy of  Soup : 91 %
#
# Line 28: Accuracy of Vegetable-Fruit : 97 %
#
# Line 29: 38.75232148170471 seconds
#
# 38.75232148170471
# batch: 4, acc: 92.41, time: 38.75232148170471
# Line 30: batch size: 8
#
# 8
# Line 31: test data set: test
#
# Line 32: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
#
# 3347 92.41 0.029
# Line 33: Accuracy of Bread : 88 %
#
# Line 34: Accuracy of DairyProduct : 81 %
#
# Line 35: Accuracy of Dessert : 97 %
#
# Line 36: Accuracy of   Egg : 88 %
#
# Line 37: Accuracy of Friedfood : 92 %
#
# Line 38: Accuracy of  Meat : 91 %
#
# Line 39: Accuracy of Noodles-Pasta : 92 %
#
# Line 40: Accuracy of  Rice : 98 %
#
# Line 41: Accuracy of Seafood : 98 %
#
# Line 42: Accuracy of  Soup : 91 %
#
# Line 43: Accuracy of Vegetable-Fruit : 97 %
#
# Line 44: 38.135311126708984 seconds
#
# 38.135311126708984
# batch: 8, acc: 92.41, time: 38.135311126708984
# Line 45: batch size: 16
#
# 16
# Line 46: test data set: test
#
# Line 47: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
#
# 3347 92.41 0.015
# Line 48: Accuracy of Bread : 88 %
#
# Line 49: Accuracy of DairyProduct : 81 %
#
# Line 50: Accuracy of Dessert : 97 %
#
# Line 51: Accuracy of   Egg : 88 %
#
# Line 52: Accuracy of Friedfood : 92 %
#
# Line 53: Accuracy of  Meat : 91 %
#
# Line 54: Accuracy of Noodles-Pasta : 92 %
#
# Line 55: Accuracy of  Rice : 98 %
#
# Line 56: Accuracy of Seafood : 98 %
#
# Line 57: Accuracy of  Soup : 91 %
#
# Line 58: Accuracy of Vegetable-Fruit : 97 %
#
# Line 59: 37.81677293777466 seconds
#
# 37.81677293777466
# batch: 16, acc: 92.41, time: 37.81677293777466
# Line 60: batch size: 32
#
# 32
# Line 61: test data set: test
#
# Line 62: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 63: Accuracy of Bread : 88 %
#
# Line 64: Accuracy of DairyProduct : 81 %
#
# Line 65: Accuracy of Dessert : 97 %
#
# Line 66: Accuracy of   Egg : 88 %
#
# Line 67: Accuracy of Friedfood : 92 %
#
# Line 68: Accuracy of  Meat : 91 %
#
# Line 69: Accuracy of Noodles-Pasta : 92 %
#
# Line 70: Accuracy of  Rice : 98 %
#
# Line 71: Accuracy of Seafood : 98 %
#
# Line 72: Accuracy of  Soup : 91 %
#
# Line 73: Accuracy of Vegetable-Fruit : 97 %
#
# Line 74: 37.712533712387085 seconds
#
# 37.712533712387085
# batch: 32, acc: 92.41, time: 37.712533712387085
# Line 75: batch size: 64
#
# 64
# Line 76: test data set: test
#
# Line 77: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
#
# 3347 92.41 0.004
# Line 78: Accuracy of Bread : 88 %
#
# Line 79: Accuracy of DairyProduct : 81 %
#
# Line 80: Accuracy of Dessert : 97 %
#
# Line 81: Accuracy of   Egg : 88 %
#
# Line 82: Accuracy of Friedfood : 92 %
#
# Line 83: Accuracy of  Meat : 91 %
#
# Line 84: Accuracy of Noodles-Pasta : 92 %
#
# Line 85: Accuracy of  Rice : 98 %
#
# Line 86: Accuracy of Seafood : 98 %
#
# Line 87: Accuracy of  Soup : 91 %
#
# Line 88: Accuracy of Vegetable-Fruit : 97 %
#
# Line 89: 38.0250678062439 seconds
#
# 38.0250678062439
# batch: 64, acc: 92.41, time: 38.0250678062439
# Line 90: batch size: 128
#
# 128
# Line 91: test data set: test
#
# Line 92: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
#
# 3347 92.41 0.002
# Line 93: Accuracy of Bread : 88 %
#
# Line 94: Accuracy of DairyProduct : 81 %
#
# Line 95: Accuracy of Dessert : 97 %
#
# Line 96: Accuracy of   Egg : 88 %
#
# Line 97: Accuracy of Friedfood : 92 %
#
# Line 98: Accuracy of  Meat : 91 %
#
# Line 99: Accuracy of Noodles-Pasta : 92 %
#
# Line 100: Accuracy of  Rice : 98 %
#
# Line 101: Accuracy of Seafood : 98 %
#
# Line 102: Accuracy of  Soup : 91 %
#
# Line 103: Accuracy of Vegetable-Fruit : 97 %
#
# Line 104: 38.359410524368286 seconds
#
# 38.359410524368286
# batch: 128, acc: 92.41, time: 38.359410524368286
# Line 105: batch size: 256
#
# 256
# Line 106: test data set: test
#
# Line 107: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
#
# 3347 92.41 0.001
# Line 108: Accuracy of Bread : 88 %
#
# Line 109: Accuracy of DairyProduct : 81 %
#
# Line 110: Accuracy of Dessert : 97 %
#
# Line 111: Accuracy of   Egg : 88 %
#
# Line 112: Accuracy of Friedfood : 92 %
#
# Line 113: Accuracy of  Meat : 91 %
#
# Line 114: Accuracy of Noodles-Pasta : 92 %
#
# Line 115: Accuracy of  Rice : 98 %
#
# Line 116: Accuracy of Seafood : 98 %
#
# Line 117: Accuracy of  Soup : 91 %
#
# Line 118: Accuracy of Vegetable-Fruit : 97 %
#
# Line 119: 38.678247690200806 seconds
#
# 38.678247690200806
# batch: 256, acc: 92.41, time: 38.678247690200806

# %%
import matplotlib.pyplot as plt
import itertools

def show_test_result(pytorch_gpu_acc, pytorch_gpu_time,
                     rt_acc, rt_time):
    
    print('Pytorch GPU Inference Time')
    print(pytorch_gpu_time)
    print('Pytorch GPU Accuracy')
    print(pytorch_gpu_acc)
    print('TensorRT Inference Time')
    print(rt_time)
    print('TensorRT Accuracy')
    print(rt_acc)
        
    fig, ax1 = plt.subplots()

    fig.set_figheight(20)
    fig.set_figwidth(20)

    ax1.set_title('TensorRT Inference Accuracy and Inference Time', fontsize=20)

    ax2 = ax1.twinx()
    ax2.figure.figsize=(120,120)
    
    l1, = ax1.plot(list(pytorch_gpu_time.keys()), list(pytorch_gpu_time.values()), 'r-')
    for i, j in zip(list(pytorch_gpu_time.keys()), list(pytorch_gpu_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='r', fontsize=20)
    
    l3, = ax1.plot(list(rt_time.keys()), list(rt_time.values()), 'b-')
    for i, j in zip(list(rt_time.keys()), list(rt_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='b', fontsize=20)
    
    l4, = ax2.plot(list(pytorch_gpu_acc.keys()), list(pytorch_gpu_acc.values()), 'r--')
    for i, j in zip(list(pytorch_gpu_acc.keys()), list(pytorch_gpu_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='r', fontsize=20)
    
    l6, = ax2.plot(list(rt_acc.keys()), list(rt_acc.values()), 'b--')
    for i, j in zip(list(rt_acc.keys()), list(rt_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='b', fontsize=20)
    
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    ax1.tick_params(axis='both', which='major', labelsize=20)
    ax2.tick_params(axis='y', which='major', labelsize=20)

    ax1.set_xlabel('Batch Size (power of 2)', fontsize=20)
    ax1.set_ylabel('Second', fontsize=20, color='r')
    ax2.set_ylabel('Accuracy (%)', fontsize=20, color='b')
    
    ax2.set(ylim=[0, 100])
    
    ax1.grid(axis='both', which='both')
    plt.legend(handles=[l1, l3, l4, l6],
               labels=['Pytorch GPU Inference Time', 'TensorRT Inference Time',
                       'Pytorch GPU Accuracy', 'TensorRT Accuracy'],
               fontsize=20, loc='right')

    plt.show()

show_test_result(pytorch_gpu_acc, pytorch_gpu_time, rt_acc, rt_time)
# Out:
# Pytorch GPU Inference Time
# OrderedDict([(1, 41.08), (2, 39.72), (3, 39.41), (4, 39.81), (5, 38.88), (6, 39.16), (7, 39.11), (8, 39.51)])
# Pytorch GPU Accuracy
# OrderedDict([(1, 92.41), (2, 92.41), (3, 92.41), (4, 92.41), (5, 92.41), (6, 92.41), (7, 92.41), (8, 92.41)])
# TensorRT Inference Time
# OrderedDict([(1, 41.16), (2, 38.75), (3, 38.14), (4, 37.82), (5, 37.71), (6, 38.03), (7, 38.36), (8, 38.68)])
# TensorRT Accuracy
# OrderedDict([(1, 92.41), (2, 92.41), (3, 92.41), (4, 92.41), (5, 92.41), (6, 92.41), (7, 92.41), (8, 92.41)])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib.animation as animation
import matplotlib.patches as mpatches

from torch.autograd import Variable
import torch
import math

import os
import sys
import re
from collections import OrderedDict

def test_ws_result(fname):

    dictionary_acc = OrderedDict()
    dictionary_time = OrderedDict()
    
    with open(fname) as fp:  
        for cnt, line in enumerate(fp):
            print("Line {}: {}".format(cnt, line))
            # work space: 2^30
            pattern = re.compile(r"work space: 2\^(\d+)")
            match = pattern.match(line)
            if match:
                work_space_str, = match.groups()
                work_space_str = '2^{}'.format(work_space_str)
                print(work_space_str)
                      
            # Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
            pattern = re.compile(r"Accuracy of the network on the (\d+) test images: (\d+.\d+)%, and loss is: (\d+.\d+)")
            match = pattern.match(line)
            if match:
                test_size_str, acc_str, loss_str = match.groups()
                print(test_size_str, acc_str, loss_str)

            # 76.6552894115448 seconds
            pattern = re.compile(r"(\d+.\d+) seconds")
            match = pattern.match(line)
            if match:
                time_str, = match.groups()
                print(time_str)
                print('work space: {:s}, acc: {:s}, time: {:s}'.
                      format(work_space_str, acc_str, time_str))

                acc = float("{:.2f}".format(float(acc_str)))
                time = float("{:.2f}".format(float(time_str)))
                
                dictionary_acc[work_space_str] = acc
                dictionary_time[work_space_str] = time
                    
    return dictionary_acc, dictionary_time
rt_acc, rt_time = test_ws_result("rt_work_space.log")
# Out:
# Line 0: work space: 2^0
#
# 2^0
# Line 1: test data set: test
#
# Line 2: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 3: Accuracy of Bread : 88 %
#
# Line 4: Accuracy of DairyProduct : 81 %
#
# Line 5: Accuracy of Dessert : 97 %
#
# Line 6: Accuracy of   Egg : 88 %
#
# Line 7: Accuracy of Friedfood : 92 %
#
# Line 8: Accuracy of  Meat : 91 %
#
# Line 9: Accuracy of Noodles-Pasta : 92 %
#
# Line 10: Accuracy of  Rice : 98 %
#
# Line 11: Accuracy of Seafood : 98 %
#
# Line 12: Accuracy of  Soup : 91 %
#
# Line 13: Accuracy of Vegetable-Fruit : 97 %
#
# Line 14: 37.5941948890686 seconds
#
# 37.5941948890686
# work space: 2^0, acc: 92.41, time: 37.5941948890686
# Line 15: work space: 2^10
#
# 2^10
# Line 16: test data set: test
#
# Line 17: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 18: Accuracy of Bread : 88 %
#
# Line 19: Accuracy of DairyProduct : 81 %
#
# Line 20: Accuracy of Dessert : 97 %
#
# Line 21: Accuracy of   Egg : 88 %
#
# Line 22: Accuracy of Friedfood : 92 %
#
# Line 23: Accuracy of  Meat : 91 %
#
# Line 24: Accuracy of Noodles-Pasta : 92 %
#
# Line 25: Accuracy of  Rice : 98 %
#
# Line 26: Accuracy of Seafood : 98 %
#
# Line 27: Accuracy of  Soup : 91 %
#
# Line 28: Accuracy of Vegetable-Fruit : 97 %
#
# Line 29: 37.57137417793274 seconds
#
# 37.57137417793274
# work space: 2^10, acc: 92.41, time: 37.57137417793274
# Line 30: work space: 2^15
#
# 2^15
# Line 31: test data set: test
#
# Line 32: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 33: Accuracy of Bread : 88 %
#
# Line 34: Accuracy of DairyProduct : 81 %
#
# Line 35: Accuracy of Dessert : 97 %
#
# Line 36: Accuracy of   Egg : 88 %
#
# Line 37: Accuracy of Friedfood : 92 %
#
# Line 38: Accuracy of  Meat : 91 %
#
# Line 39: Accuracy of Noodles-Pasta : 92 %
#
# Line 40: Accuracy of  Rice : 98 %
#
# Line 41: Accuracy of Seafood : 98 %
#
# Line 42: Accuracy of  Soup : 91 %
#
# Line 43: Accuracy of Vegetable-Fruit : 97 %
#
# Line 44: 37.51393222808838 seconds
#
# 37.51393222808838
# work space: 2^15, acc: 92.41, time: 37.51393222808838
# Line 45: work space: 2^20
#
# 2^20
# Line 46: test data set: test
#
# Line 47: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 48: Accuracy of Bread : 88 %
#
# Line 49: Accuracy of DairyProduct : 81 %
#
# Line 50: Accuracy of Dessert : 97 %
#
# Line 51: Accuracy of   Egg : 88 %
#
# Line 52: Accuracy of Friedfood : 92 %
#
# Line 53: Accuracy of  Meat : 91 %
#
# Line 54: Accuracy of Noodles-Pasta : 92 %
#
# Line 55: Accuracy of  Rice : 98 %
#
# Line 56: Accuracy of Seafood : 98 %
#
# Line 57: Accuracy of  Soup : 91 %
#
# Line 58: Accuracy of Vegetable-Fruit : 97 %
#
# Line 59: 37.482604026794434 seconds
#
# 37.482604026794434
# work space: 2^20, acc: 92.41, time: 37.482604026794434
# Line 60: work space: 2^27
#
# 2^27
# Line 61: test data set: test
#
# Line 62: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 63: Accuracy of Bread : 88 %
#
# Line 64: Accuracy of DairyProduct : 81 %
#
# Line 65: Accuracy of Dessert : 97 %
#
# Line 66: Accuracy of   Egg : 88 %
#
# Line 67: Accuracy of Friedfood : 92 %
#
# Line 68: Accuracy of  Meat : 91 %
#
# Line 69: Accuracy of Noodles-Pasta : 92 %
#
# Line 70: Accuracy of  Rice : 98 %
#
# Line 71: Accuracy of Seafood : 98 %
#
# Line 72: Accuracy of  Soup : 91 %
#
# Line 73: Accuracy of Vegetable-Fruit : 97 %
#
# Line 74: 38.040149450302124 seconds
#
# 38.040149450302124
# work space: 2^27, acc: 92.41, time: 38.040149450302124
# Line 75: work space: 2^30
#
# 2^30
# Line 76: test data set: test
#
# Line 77: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 78: Accuracy of Bread : 88 %
#
# Line 79: Accuracy of DairyProduct : 81 %
#
# Line 80: Accuracy of Dessert : 97 %
#
# Line 81: Accuracy of   Egg : 88 %
#
# Line 82: Accuracy of Friedfood : 92 %
#
# Line 83: Accuracy of  Meat : 91 %
#
# Line 84: Accuracy of Noodles-Pasta : 92 %
#
# Line 85: Accuracy of  Rice : 98 %
#
# Line 86: Accuracy of Seafood : 98 %
#
# Line 87: Accuracy of  Soup : 91 %
#
# Line 88: Accuracy of Vegetable-Fruit : 97 %
#
# Line 89: 37.74765706062317 seconds
#
# 37.74765706062317
# work space: 2^30, acc: 92.41, time: 37.74765706062317
# Line 90: work space: 2^31
#
# 2^31
# Line 91: test data set: test
#
# Line 92: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 93: Accuracy of Bread : 88 %
#
# Line 94: Accuracy of DairyProduct : 81 %
#
# Line 95: Accuracy of Dessert : 97 %
#
# Line 96: Accuracy of   Egg : 88 %
#
# Line 97: Accuracy of Friedfood : 92 %
#
# Line 98: Accuracy of  Meat : 91 %
#
# Line 99: Accuracy of Noodles-Pasta : 92 %
#
# Line 100: Accuracy of  Rice : 98 %
#
# Line 101: Accuracy of Seafood : 98 %
#
# Line 102: Accuracy of  Soup : 91 %
#
# Line 103: Accuracy of Vegetable-Fruit : 97 %
#
# Line 104: 37.32978677749634 seconds
#
# 37.32978677749634
# work space: 2^31, acc: 92.41, time: 37.32978677749634

# %%
import matplotlib.pyplot as plt
import itertools

def show_ws_test_result(rt_acc, rt_time):
    
    print('TensorRT Inference Time')
    print(rt_time)
    print('TensorRT Accuracy')
    print(rt_acc)
        
    fig, ax1 = plt.subplots()

    fig.set_figheight(20)
    fig.set_figwidth(20)

    ax1.set_title('TensorRT Inference Accuracy and Inference Time', fontsize=20)

    ax2 = ax1.twinx()
    ax2.figure.figsize=(120,120)
    
    l3, = ax1.plot(list(rt_time.keys()), list(rt_time.values()), 'r--')
    for i, j in zip(list(rt_time.keys()), list(rt_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='r', fontsize=20)
    
    l6, = ax2.plot(list(rt_acc.keys()), list(rt_acc.values()), 'b-')
    for i, j in zip(list(rt_acc.keys()), list(rt_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='b', fontsize=20)
    
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    ax1.tick_params(axis='both', which='major', labelsize=20)
    ax2.tick_params(axis='y', which='major', labelsize=20)

    ax1.set_xlabel('Batch Size (power of 2)', fontsize=20)
    ax1.set_ylabel('Second', fontsize=20, color='r')
    ax2.set_ylabel('Accuracy (%)', fontsize=20, color='b')
    
    ax2.set(ylim=[0, 100])
    ax1.set(ylim=[35, 40])
    
    ax1.grid(axis='both', which='both')
    plt.legend(handles=[l3, l6],
               labels=['TensorRT Inference Time', 'TensorRT Accuracy'],
               fontsize=20, loc='right')

    plt.show()

show_ws_test_result(rt_acc, rt_time)
# Out:
# TensorRT Inference Time
# OrderedDict([('2^0', 37.59), ('2^10', 37.57), ('2^15', 37.51), ('2^20', 37.48), ('2^27', 38.04), ('2^30', 37.75), ('2^31', 37.33)])
# TensorRT Accuracy
# OrderedDict([('2^0', 92.41), ('2^10', 92.41), ('2^15', 92.41), ('2^20', 92.41), ('2^27', 92.41), ('2^30', 92.41), ('2^31', 92.41)])
